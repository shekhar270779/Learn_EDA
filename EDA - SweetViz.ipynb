# %% [markdown]
# ### Sweetviz
# * Sweetviz is an open source Python library that generates beautiful, high-density visualizations to kickstart EDA (Exploratory Data Analysis) with a single line of code. Output is a fully self-contained HTML application.
# * Sweetviz is a powerful package that helps you visualize your data in an extremely intuitive manner. It shows all the plots specific to each and every column and also lists out the Statistical Summary of each column

# %%
import pandas as pd

# %%
# install library - pip install sweetviz
import sweetviz

# %%
pd.__version__
# Out:
# '1.0.3'

# %%
# !pip freeze | grep sweetviz
# Out:
# sweetviz==1.0a7

# %% [markdown]
# * Sweetviz is in the ALPHA TESTING PHASE
# * Sweetviz currently supports Python 3.6+ and Pandas 0.25.3+. Reports are output using the base "os" module, so custom environments such as Google Colab which require custom file operations are not yet supported
# * Currently the only rendering supported is to a standalone HTML file

# %%
# load data
house_train = pd.read_csv(r'./data/house_train.csv')
house_test = pd.read_csv(r'./data/house_test.csv')

# %%
# check dimensions
house_train.shape, house_test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
house_train.head(n=3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %% [markdown]
# In this case we have used house price predictions data. This has 80 columns, this kind of heavy data is hard for pandas profiling to handle. But sweetviz handles it with ease.

# %% [markdown]
# ### Visualization w.r.t target variable:
# Sweetviz offers a platform to compare train data in terms of target variable which in this case is Sales Price.

# %%
report = sweetviz.analyze([house_train, 'Train'], target_feat = 'SalePrice')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |▎                    | [  1%]   00:00  -> (00:27 left)
# :TARGET::                          |▎                    | [  1%]   00:00  -> (00:27 left)
# :TARGET::                          |▌                    | [  2%]   00:02  -> (01:06 left)
# :Id:                               |▌                    | [  2%]   00:02  -> (01:06 left)
# :Id:                               |▊                    | [  4%]   00:03  -> (01:07 left)
# :MSSubClass:                       |▊                    | [  4%]   00:03  -> (01:07 left)
# :MSSubClass:                       |█                    | [  5%]   00:04  -> (01:08 left)
# :MSZoning:                         |█                    | [  5%]   00:04  -> (01:08 left)
# :MSZoning:                         |█▎                   | [  6%]   00:05  -> (01:14 left)
# :LotFrontage:                      |█▎                   | [  6%]   00:05  -> (01:14 left)
# :LotFrontage:                      |█▌                   | [  7%]   00:06  -> (01:15 left)
# :LotArea:                          |█▌                   | [  7%]   00:06  -> (01:15 left)
# :LotArea:                          |█▊                   | [  9%]   00:07  -> (01:18 left)
# :Street:                           |█▊                   | [  9%]   00:07  -> (01:18 left)
# :Street:                           |██                   | [ 10%]   00:08  -> (01:05 left)
# :Alley:                            |██                   | [ 10%]   00:08  -> (01:05 left)
# :Alley:                            |██▎                  | [ 11%]   00:08  -> (00:56 left)
# :LotShape:                         |██▎                  | [ 11%]   00:08  -> (00:56 left)
# :LotShape:                         |██▌                  | [ 12%]   00:09  -> (00:50 left)
# :LandContour:                      |██▌                  | [ 12%]   00:09  -> (00:50 left)
# :LandContour:                      |██▊                  | [ 13%]   00:09  -> (00:48 left)
# :Utilities:                        |██▊                  | [ 13%]   00:09  -> (00:48 left)
# :Utilities:                        |███                  | [ 15%]   00:10  -> (00:43 left)
# :LotConfig:                        |███                  | [ 15%]   00:10  -> (00:43 left)
# :LotConfig:                        |███▎                 | [ 16%]   00:10  -> (00:45 left)
# :LandSlope:                        |███▎                 | [ 16%]   00:10  -> (00:45 left)
# :LandSlope:                        |███▌                 | [ 17%]   00:11  -> (00:42 left)
# :Neighborhood:                     |███▌                 | [ 17%]   00:11  -> (00:42 left)
# :Neighborhood:                     |███▊                 | [ 18%]   00:12  -> (00:46 left)
# :Condition1:                       |███▊                 | [ 18%]   00:12  -> (00:46 left)
# :Condition1:                       |████                 | [ 20%]   00:13  -> (00:46 left)
# :Condition2:                       |████                 | [ 20%]   00:13  -> (00:46 left)
# :Condition2:                       |████▎                | [ 21%]   00:13  -> (00:44 left)
# :BldgType:                         |████▎                | [ 21%]   00:13  -> (00:44 left)
# :BldgType:                         |████▌                | [ 22%]   00:14  -> (00:42 left)
# :HouseStyle:                       |████▌                | [ 22%]   00:14  -> (00:42 left)
# :HouseStyle:                       |████▊                | [ 23%]   00:14  -> (00:40 left)
# :OverallQual:                      |████▊                | [ 23%]   00:14  -> (00:40 left)
# :OverallQual:                      |█████                | [ 24%]   00:15  -> (00:39 left)
# :OverallCond:                      |█████                | [ 24%]   00:15  -> (00:39 left)
# :OverallCond:                      |█████▍               | [ 26%]   00:16  -> (00:37 left)
# :YearBuilt:                        |█████▍               | [ 26%]   00:16  -> (00:37 left)
# :YearBuilt:                        |█████▋               | [ 27%]   00:17  -> (00:48 left)
# :YearRemodAdd:                     |█████▋               | [ 27%]   00:17  -> (00:48 left)
# :YearRemodAdd:                     |█████▉               | [ 28%]   00:18  -> (00:50 left)
# :RoofStyle:                        |█████▉               | [ 28%]   00:18  -> (00:50 left)
# :RoofStyle:                        |██████▏              | [ 29%]   00:19  -> (00:45 left)
# :RoofMatl:                         |██████▏              | [ 29%]   00:19  -> (00:45 left)
# :RoofMatl:                         |██████▍              | [ 30%]   00:19  -> (00:40 left)
# :Exterior1st:                      |██████▍              | [ 30%]   00:19  -> (00:40 left)
# :Exterior1st:                      |██████▋              | [ 32%]   00:20  -> (00:39 left)
# :Exterior2nd:                      |██████▋              | [ 32%]   00:20  -> (00:39 left)
# :Exterior2nd:                      |██████▉              | [ 33%]   00:20  -> (00:36 left)
# :MasVnrType:                       |██████▉              | [ 33%]   00:20  -> (00:36 left)
# :MasVnrType:                       |███████▏             | [ 34%]   00:21  -> (00:34 left)
# :MasVnrArea:                       |███████▏             | [ 34%]   00:21  -> (00:34 left)
# :MasVnrArea:                       |███████▍             | [ 35%]   00:22  -> (00:44 left)
# :ExterQual:                        |███████▍             | [ 35%]   00:22  -> (00:44 left)
# :ExterQual:                        |███████▋             | [ 37%]   00:23  -> (00:38 left)
# :ExterCond:                        |███████▋             | [ 37%]   00:23  -> (00:38 left)
# :ExterCond:                        |███████▉             | [ 38%]   00:23  -> (00:35 left)
# :Foundation:                       |███████▉             | [ 38%]   00:23  -> (00:35 left)
# :Foundation:                       |████████▏            | [ 39%]   00:24  -> (00:32 left)
# :BsmtQual:                         |████████▏            | [ 39%]   00:24  -> (00:32 left)
# :BsmtQual:                         |████████▍            | [ 40%]   00:24  -> (00:30 left)
# :BsmtCond:                         |████████▍            | [ 40%]   00:24  -> (00:30 left)
# :BsmtCond:                         |████████▋            | [ 41%]   00:25  -> (00:28 left)
# :BsmtExposure:                     |████████▋            | [ 41%]   00:25  -> (00:28 left)
# :BsmtExposure:                     |████████▉            | [ 43%]   00:25  -> (00:27 left)
# :BsmtFinType1:                     |████████▉            | [ 43%]   00:25  -> (00:27 left)
# :BsmtFinType1:                     |█████████▏           | [ 44%]   00:26  -> (00:26 left)
# :BsmtFinSF1:                       |█████████▏           | [ 44%]   00:26  -> (00:26 left)
# :BsmtFinSF1:                       |█████████▍           | [ 45%]   00:27  -> (00:32 left)
# :BsmtFinType2:                     |█████████▍           | [ 45%]   00:27  -> (00:32 left)
# :BsmtFinType2:                     |█████████▋           | [ 46%]   00:28  -> (00:31 left)
# :BsmtFinSF2:                       |█████████▋           | [ 46%]   00:28  -> (00:31 left)
# :BsmtFinSF2:                       |█████████▉           | [ 48%]   00:29  -> (00:37 left)
# :BsmtUnfSF:                        |█████████▉           | [ 48%]   00:29  -> (00:37 left)
# :BsmtUnfSF:                        |██████████▏          | [ 49%]   00:30  -> (00:42 left)
# :TotalBsmtSF:                      |██████████▏          | [ 49%]   00:30  -> (00:42 left)
# :TotalBsmtSF:                      |██████████▌          | [ 50%]   00:31  -> (00:41 left)
# :Heating:                          |██████████▌          | [ 50%]   00:31  -> (00:41 left)
# :Heating:                          |██████████▊          | [ 51%]   00:32  -> (00:35 left)
# :HeatingQC:                        |██████████▊          | [ 51%]   00:32  -> (00:35 left)
# :HeatingQC:                        |███████████          | [ 52%]   00:33  -> (00:30 left)
# :CentralAir:                       |███████████          | [ 52%]   00:33  -> (00:30 left)
# :CentralAir:                       |███████████▎         | [ 54%]   00:33  -> (00:27 left)
# :Electrical:                       |███████████▎         | [ 54%]   00:33  -> (00:27 left)
# :Electrical:                       |███████████▌         | [ 55%]   00:34  -> (00:25 left)
# :1stFlrSF:                         |███████████▌         | [ 55%]   00:34  -> (00:25 left)
# :1stFlrSF:                         |███████████▊         | [ 56%]   00:35  -> (00:28 left)
# :2ndFlrSF:                         |███████████▊         | [ 56%]   00:35  -> (00:28 left)
# :2ndFlrSF:                         |████████████         | [ 57%]   00:36  -> (00:29 left)
# :LowQualFinSF:                     |████████████         | [ 57%]   00:36  -> (00:29 left)
# :LowQualFinSF:                     |████████████▎        | [ 59%]   00:37  -> (00:31 left)
# :GrLivArea:                        |████████████▎        | [ 59%]   00:37  -> (00:31 left)
# :GrLivArea:                        |████████████▌        | [ 60%]   00:38  -> (00:34 left)
# :BsmtFullBath:                     |████████████▌        | [ 60%]   00:38  -> (00:34 left)
# :BsmtFullBath:                     |████████████▊        | [ 61%]   00:39  -> (00:28 left)
# :BsmtHalfBath:                     |████████████▊        | [ 61%]   00:39  -> (00:28 left)
# :BsmtHalfBath:                     |█████████████        | [ 62%]   00:39  -> (00:24 left)
# :FullBath:                         |█████████████        | [ 62%]   00:39  -> (00:24 left)
# :FullBath:                         |█████████████▎       | [ 63%]   00:40  -> (00:21 left)
# :HalfBath:                         |█████████████▎       | [ 63%]   00:40  -> (00:21 left)
# :HalfBath:                         |█████████████▌       | [ 65%]   00:40  -> (00:19 left)
# :BedroomAbvGr:                     |█████████████▌       | [ 65%]   00:40  -> (00:19 left)
# :BedroomAbvGr:                     |█████████████▊       | [ 66%]   00:41  -> (00:18 left)
# :KitchenAbvGr:                     |█████████████▊       | [ 66%]   00:41  -> (00:18 left)
# :KitchenAbvGr:                     |██████████████       | [ 67%]   00:41  -> (00:16 left)
# :KitchenQual:                      |██████████████       | [ 67%]   00:41  -> (00:16 left)
# :KitchenQual:                      |██████████████▎      | [ 68%]   00:42  -> (00:15 left)
# :TotRmsAbvGrd:                     |██████████████▎      | [ 68%]   00:42  -> (00:15 left)
# :TotRmsAbvGrd:                     |██████████████▌      | [ 70%]   00:43  -> (00:18 left)
# :Functional:                       |██████████████▌      | [ 70%]   00:43  -> (00:18 left)
# :Functional:                       |██████████████▊      | [ 71%]   00:44  -> (00:17 left)
# :Fireplaces:                       |██████████████▊      | [ 71%]   00:44  -> (00:17 left)
# :Fireplaces:                       |███████████████      | [ 72%]   00:45  -> (00:16 left)
# :FireplaceQu:                      |███████████████      | [ 72%]   00:45  -> (00:16 left)
# :FireplaceQu:                      |███████████████▎     | [ 73%]   00:45  -> (00:15 left)
# :GarageType:                       |███████████████▎     | [ 73%]   00:45  -> (00:15 left)
# :GarageType:                       |███████████████▌     | [ 74%]   00:46  -> (00:14 left)
# :GarageYrBlt:                      |███████████████▌     | [ 74%]   00:46  -> (00:14 left)
# :GarageYrBlt:                      |███████████████▉     | [ 76%]   00:47  -> (00:16 left)
# :GarageFinish:                     |███████████████▉     | [ 76%]   00:47  -> (00:16 left)
# :GarageFinish:                     |████████████████▏    | [ 77%]   00:47  -> (00:13 left)
# :GarageCars:                       |████████████████▏    | [ 77%]   00:47  -> (00:13 left)
# :GarageCars:                       |████████████████▍    | [ 78%]   00:48  -> (00:12 left)
# :GarageArea:                       |████████████████▍    | [ 78%]   00:48  -> (00:12 left)
# :GarageArea:                       |████████████████▋    | [ 79%]   00:49  -> (00:13 left)
# :GarageQual:                       |████████████████▋    | [ 79%]   00:49  -> (00:13 left)
# :GarageQual:                       |████████████████▉    | [ 80%]   00:50  -> (00:11 left)
# :GarageCond:                       |████████████████▉    | [ 80%]   00:50  -> (00:11 left)
# :GarageCond:                       |█████████████████▏   | [ 82%]   00:51  -> (00:12 left)
# :PavedDrive:                       |█████████████████▏   | [ 82%]   00:51  -> (00:12 left)
# :PavedDrive:                       |█████████████████▍   | [ 83%]   00:51  -> (00:10 left)
# :WoodDeckSF:                       |█████████████████▍   | [ 83%]   00:51  -> (00:10 left)
# :WoodDeckSF:                       |█████████████████▋   | [ 84%]   00:52  -> (00:10 left)
# :OpenPorchSF:                      |█████████████████▋   | [ 84%]   00:52  -> (00:10 left)
# :OpenPorchSF:                      |█████████████████▉   | [ 85%]   00:53  -> (00:10 left)
# :EnclosedPorch:                    |█████████████████▉   | [ 85%]   00:53  -> (00:10 left)
# :EnclosedPorch:                    |██████████████████▏  | [ 87%]   00:54  -> (00:10 left)
# :3SsnPorch:                        |██████████████████▏  | [ 87%]   00:54  -> (00:10 left)
# :3SsnPorch:                        |██████████████████▍  | [ 88%]   00:55  -> (00:09 left)
# :ScreenPorch:                      |██████████████████▍  | [ 88%]   00:55  -> (00:09 left)
# :ScreenPorch:                      |██████████████████▋  | [ 89%]   00:56  -> (00:08 left)
# :PoolArea:                         |██████████████████▋  | [ 89%]   00:56  -> (00:08 left)
# :PoolArea:                         |██████████████████▉  | [ 90%]   00:57  -> (00:06 left)
# :PoolQC:                           |██████████████████▉  | [ 90%]   00:57  -> (00:06 left)
# :Fence:                            |███████████████████▏ | [ 91%]   00:57  -> (00:06 left)
# :Fence:                            |███████████████████▍ | [ 93%]   00:58  -> (00:04 left)
# :MiscFeature:                      |███████████████████▍ | [ 93%]   00:58  -> (00:04 left)
# :MiscFeature:                      |███████████████████▋ | [ 94%]   00:58  -> (00:03 left)
# :MiscVal:                          |███████████████████▋ | [ 94%]   00:58  -> (00:03 left)
# :MiscVal:                          |███████████████████▉ | [ 95%]   00:59  -> (00:03 left)
# :MoSold:                           |███████████████████▉ | [ 95%]   00:59  -> (00:03 left)
# :MoSold:                           |████████████████████▏| [ 96%]   01:01  -> (00:02 left)
# :YrSold:                           |████████████████████▏| [ 96%]   01:01  -> (00:02 left)
# :YrSold:                           |████████████████████▍| [ 98%]   01:02  -> (00:01 left)
# :SaleType:                         |████████████████████▍| [ 98%]   01:02  -> (00:01 left)
# :SaleType:                         |████████████████████▋| [ 99%]   01:02  -> (00:00 left)
# :SaleCondition:                    |████████████████████▋| [ 99%]   01:02  -> (00:00 left)
# :SaleCondition:                    |█████████████████████| [100%]   01:03  -> (00:00 left)
# :FEATURES DONE:                    |█████████████████████| [100%]   01:03  -> (00:00 left)
#
#                                    |                         | [  0%]   00:00  -> (? left)
# :Processing Pairwise Features:     |                         | [  0%]   00:00  -> (? left)
# :Processing Pairwise Features:     |▎                    | [  1%]   00:00  -> (00:18 left)
# :Processing Pairwise Features:     |█                    | [  5%]   00:00  -> (00:14 left)
# :Processing Pairwise Features:     |█▊                   | [  9%]   00:00  -> (00:11 left)
# :Processing Pairwise Features:     |██                   | [ 10%]   00:00  -> (00:12 left)
# :Processing Pairwise Features:     |██▎                  | [ 11%]   00:01  -> (00:13 left)
# :Processing Pairwise Features:     |██▌                  | [ 12%]   00:01  -> (00:12 left)
# :Processing Pairwise Features:     |██▊                  | [ 14%]   00:01  -> (00:12 left)
# :Processing Pairwise Features:     |███                  | [ 15%]   00:01  -> (00:17 left)
# :Processing Pairwise Features:     |███▎                 | [ 16%]   00:02  -> (00:16 left)
# :Processing Pairwise Features:     |███▋                 | [ 17%]   00:02  -> (00:16 left)
# :Processing Pairwise Features:     |███▉                 | [ 19%]   00:02  -> (00:14 left)
# :Processing Pairwise Features:     |████▏                | [ 20%]   00:02  -> (00:13 left)
# :Processing Pairwise Features:     |████▍                | [ 21%]   00:02  -> (00:13 left)
# :Processing Pairwise Features:     |████▋                | [ 22%]   00:03  -> (00:12 left)
# :Processing Pairwise Features:     |████▉                | [ 23%]   00:03  -> (00:13 left)
# :Processing Pairwise Features:     |█████▏               | [ 25%]   00:03  -> (00:12 left)
# :Processing Pairwise Features:     |█████▉               | [ 28%]   00:03  -> (00:09 left)
# :Processing Pairwise Features:     |██████▏              | [ 30%]   00:03  -> (00:10 left)
# :Processing Pairwise Features:     |██████▍              | [ 31%]   00:04  -> (00:10 left)
# :Processing Pairwise Features:     |██████▋              | [ 32%]   00:04  -> (00:14 left)
# :Processing Pairwise Features:     |███████              | [ 33%]   00:04  -> (00:12 left)
# :Processing Pairwise Features:     |███████▌             | [ 36%]   00:05  -> (00:10 left)
# :Processing Pairwise Features:     |███████▊             | [ 37%]   00:05  -> (00:09 left)
# :Processing Pairwise Features:     |████████             | [ 38%]   00:05  -> (00:09 left)
# :Processing Pairwise Features:     |████████▎            | [ 40%]   00:05  -> (00:09 left)
# :Processing Pairwise Features:     |████████▌            | [ 41%]   00:05  -> (00:09 left)
# :Processing Pairwise Features:     |████████▊            | [ 42%]   00:06  -> (00:09 left)
# :Processing Pairwise Features:     |█████████            | [ 43%]   00:06  -> (00:08 left)
# :Processing Pairwise Features:     |█████████▌           | [ 46%]   00:06  -> (00:07 left)
# :Processing Pairwise Features:     |██████████▋          | [ 51%]   00:06  -> (00:05 left)
# :Processing Pairwise Features:     |██████████▉          | [ 52%]   00:06  -> (00:07 left)
# :Processing Pairwise Features:     |███████████▏         | [ 53%]   00:07  -> (00:07 left)
# :Processing Pairwise Features:     |███████████▍         | [ 54%]   00:07  -> (00:06 left)
# :Processing Pairwise Features:     |████████████▋        | [ 60%]   00:07  -> (00:04 left)
# :Processing Pairwise Features:     |█████████████▏       | [ 63%]   00:07  -> (00:04 left)
# :Processing Pairwise Features:     |█████████████▍       | [ 64%]   00:08  -> (00:04 left)
# :Processing Pairwise Features:     |█████████████▋       | [ 65%]   00:08  -> (00:04 left)
# :Processing Pairwise Features:     |██████████████       | [ 67%]   00:08  -> (00:04 left)
# :Processing Pairwise Features:     |██████████████▎      | [ 68%]   00:08  -> (00:04 left)
# :Processing Pairwise Features:     |██████████████▊      | [ 70%]   00:08  -> (00:03 left)
# :Processing Pairwise Features:     |███████████████      | [ 72%]   00:09  -> (00:04 left)
# :Processing Pairwise Features:     |███████████████▎     | [ 73%]   00:09  -> (00:04 left)
# :Processing Pairwise Features:     |███████████████▌     | [ 74%]   00:09  -> (00:04 left)
# :Processing Pairwise Features:     |████████████████     | [ 77%]   00:09  -> (00:03 left)
# :Processing Pairwise Features:     |████████████████▎    | [ 78%]   00:09  -> (00:03 left)
# :Processing Pairwise Features:     |████████████████▊    | [ 80%]   00:10  -> (00:02 left)
# :Processing Pairwise Features:     |█████████████████    | [ 81%]   00:10  -> (00:02 left)
# :Processing Pairwise Features:     |█████████████████▎   | [ 83%]   00:10  -> (00:02 left)
# :Processing Pairwise Features:     |██████████████████▉  | [ 90%]   00:10  -> (00:01 left)
# :Processing Pairwise Features:     |███████████████████▍ | [ 93%]   00:10  -> (00:00 left)
# :Processing Pairwise Features:     |███████████████████▉ | [ 95%]   00:11  -> (00:00 left)
# :Processing Pairwise Features:     |████████████████████▍| [ 98%]   00:11  -> (00:00 left)
# :Processing Pairwise Features:     |████████████████████▋| [ 99%]   00:11  -> (00:00 left)
# :Processing Pairwise Features:     |█████████████████████| [100%]   00:11  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:11  -> (00:00 left)
# Creating Associations graph... DONE!

# %% [markdown]
# Here `Train` is just a name you are supposed to give to represent your train data in sweetviz and your target feature is SalePrice.  Once this code is executed it runs for about 10-12 seconds and processes pairwise features and also creates association graphs in  this step.

# %%
type(report)
# Out:
# sweetviz.dataframe_report.DataframeReport

# %%
# render the output as html
report.show_html(r'./data/output/House_train_report.html')

# %% [markdown]
# * Once we execute this code we are presented  with the beautiful visualization by Sweetviz.
# * The top section gives information about the train data.

# %% [markdown]
# * We get information about each feature, its distribution and its relation with target variable.
#   For example let us look at the feature `MSSubClass`. Here the blue lines above the bars in the
#   picture represent the Average SalePrice (target variable).
#   We are provided wih the entire Statistical summary of this feature since this is a continuous feature.
# * In case of categorical features you may not find the statistical summary because this part behaves exactly in the manner .describe() behaves.

# %% [markdown]
# ### Comparison of train and test datasets.
#
# Sweetviz offers an option where we can compare train and test datasets with respect to target variable.

# %%
train_test_comp_report = sweetviz.compare([house_train, 'Train'], [house_test, 'Test'], 
                                         target_feat = 'SalePrice')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |▎                    | [  1%]   00:00  -> (00:56 left)
# :TARGET::                          |▎                    | [  1%]   00:00  -> (00:56 left)
# :TARGET::                          |▌                    | [  2%]   00:01  -> (00:56 left)
# :Id:                               |▌                    | [  2%]   00:01  -> (00:56 left)
# :Id:                               |▊                    | [  4%]   00:02  -> (01:10 left)
# :MSSubClass:                       |▊                    | [  4%]   00:02  -> (01:10 left)
# :MSSubClass:                       |█                    | [  5%]   00:03  -> (01:14 left)
# :MSZoning:                         |█                    | [  5%]   00:03  -> (01:14 left)
# :MSZoning:                         |█▎                   | [  6%]   00:04  -> (01:04 left)
# :LotFrontage:                      |█▎                   | [  6%]   00:04  -> (01:04 left)
# :LotFrontage:                      |█▌                   | [  7%]   00:05  -> (01:13 left)
# :LotArea:                          |█▌                   | [  7%]   00:05  -> (01:13 left)
# :LotArea:                          |█▊                   | [  9%]   00:08  -> (01:51 left)
# :Street:                           |█▊                   | [  9%]   00:08  -> (01:51 left)
# :Street:                           |██                   | [ 10%]   00:08  -> (01:28 left)
# :Alley:                            |██                   | [ 10%]   00:08  -> (01:28 left)
# :Alley:                            |██▎                  | [ 11%]   00:09  -> (01:11 left)
# :LotShape:                         |██▎                  | [ 11%]   00:09  -> (01:11 left)
# :LotShape:                         |██▌                  | [ 12%]   00:09  -> (00:59 left)
# :LandContour:                      |██▌                  | [ 12%]   00:09  -> (00:59 left)
# :LandContour:                      |██▊                  | [ 13%]   00:10  -> (00:51 left)
# :Utilities:                        |██▊                  | [ 13%]   00:10  -> (00:51 left)
# :Utilities:                        |███                  | [ 15%]   00:10  -> (00:46 left)
# :LotConfig:                        |███                  | [ 15%]   00:10  -> (00:46 left)
# :LotConfig:                        |███▎                 | [ 16%]   00:11  -> (00:43 left)
# :LandSlope:                        |███▎                 | [ 16%]   00:11  -> (00:43 left)
# :LandSlope:                        |███▌                 | [ 17%]   00:11  -> (00:39 left)
# :Neighborhood:                     |███▌                 | [ 17%]   00:11  -> (00:39 left)
# :Neighborhood:                     |███▊                 | [ 18%]   00:12  -> (00:43 left)
# :Condition1:                       |███▊                 | [ 18%]   00:12  -> (00:43 left)
# :Condition1:                       |████                 | [ 20%]   00:13  -> (00:43 left)
# :Condition2:                       |████                 | [ 20%]   00:13  -> (00:43 left)
# :Condition2:                       |████▎                | [ 21%]   00:13  -> (00:42 left)
# :BldgType:                         |████▎                | [ 21%]   00:13  -> (00:42 left)
# :BldgType:                         |████▌                | [ 22%]   00:14  -> (00:47 left)
# :HouseStyle:                       |████▌                | [ 22%]   00:14  -> (00:47 left)
# :HouseStyle:                       |████▊                | [ 23%]   00:15  -> (00:50 left)
# :OverallQual:                      |████▊                | [ 23%]   00:15  -> (00:50 left)
# :OverallQual:                      |█████                | [ 24%]   00:16  -> (00:53 left)
# :OverallCond:                      |█████                | [ 24%]   00:16  -> (00:53 left)
# :OverallCond:                      |█████▍               | [ 26%]   00:17  -> (00:52 left)
# :YearBuilt:                        |█████▍               | [ 26%]   00:17  -> (00:52 left)
# :YearBuilt:                        |█████▋               | [ 27%]   00:18  -> (00:54 left)
# :YearRemodAdd:                     |█████▋               | [ 27%]   00:18  -> (00:54 left)
# :YearRemodAdd:                     |█████▉               | [ 28%]   00:19  -> (00:56 left)
# :RoofStyle:                        |█████▉               | [ 28%]   00:19  -> (00:56 left)
# :RoofStyle:                        |██████▏              | [ 29%]   00:20  -> (00:52 left)
# :RoofMatl:                         |██████▏              | [ 29%]   00:20  -> (00:52 left)
# :RoofMatl:                         |██████▍              | [ 30%]   00:21  -> (00:49 left)
# :Exterior1st:                      |██████▍              | [ 30%]   00:21  -> (00:49 left)
# :Exterior1st:                      |██████▋              | [ 32%]   00:22  -> (00:51 left)
# :Exterior2nd:                      |██████▋              | [ 32%]   00:22  -> (00:51 left)
# :Exterior2nd:                      |██████▉              | [ 33%]   00:23  -> (00:48 left)
# :MasVnrType:                       |██████▉              | [ 33%]   00:23  -> (00:48 left)
# :MasVnrType:                       |███████▏             | [ 34%]   00:24  -> (00:54 left)
# :MasVnrArea:                       |███████▏             | [ 34%]   00:24  -> (00:54 left)
# :MasVnrArea:                       |███████▍             | [ 35%]   00:25  -> (00:53 left)
# :ExterQual:                        |███████▍             | [ 35%]   00:25  -> (00:53 left)
# :ExterQual:                        |███████▋             | [ 37%]   00:26  -> (00:44 left)
# :ExterCond:                        |███████▋             | [ 37%]   00:26  -> (00:44 left)
# :ExterCond:                        |███████▉             | [ 38%]   00:26  -> (00:39 left)
# :Foundation:                       |███████▉             | [ 38%]   00:26  -> (00:39 left)
# :Foundation:                       |████████▏            | [ 39%]   00:27  -> (00:35 left)
# :BsmtQual:                         |████████▏            | [ 39%]   00:27  -> (00:35 left)
# :BsmtQual:                         |████████▍            | [ 40%]   00:27  -> (00:31 left)
# :BsmtCond:                         |████████▍            | [ 40%]   00:27  -> (00:31 left)
# :BsmtCond:                         |████████▋            | [ 41%]   00:28  -> (00:30 left)
# :BsmtExposure:                     |████████▋            | [ 41%]   00:28  -> (00:30 left)
# :BsmtExposure:                     |████████▉            | [ 43%]   00:28  -> (00:29 left)
# :BsmtFinType1:                     |████████▉            | [ 43%]   00:28  -> (00:29 left)
# :BsmtFinType1:                     |█████████▏           | [ 44%]   00:29  -> (00:28 left)
# :BsmtFinSF1:                       |█████████▏           | [ 44%]   00:29  -> (00:28 left)
# :BsmtFinSF1:                       |█████████▍           | [ 45%]   00:30  -> (00:32 left)
# :BsmtFinType2:                     |█████████▍           | [ 45%]   00:30  -> (00:32 left)
# :BsmtFinType2:                     |█████████▋           | [ 46%]   00:30  -> (00:29 left)
# :BsmtFinSF2:                       |█████████▋           | [ 46%]   00:30  -> (00:29 left)
# :BsmtFinSF2:                       |█████████▉           | [ 48%]   00:32  -> (00:34 left)
# :BsmtUnfSF:                        |█████████▉           | [ 48%]   00:32  -> (00:34 left)
# :BsmtUnfSF:                        |██████████▏          | [ 49%]   00:33  -> (00:36 left)
# :TotalBsmtSF:                      |██████████▏          | [ 49%]   00:33  -> (00:36 left)
# :TotalBsmtSF:                      |██████████▌          | [ 50%]   00:34  -> (00:36 left)
# :Heating:                          |██████████▌          | [ 50%]   00:34  -> (00:36 left)
# :Heating:                          |██████████▊          | [ 51%]   00:34  -> (00:32 left)
# :HeatingQC:                        |██████████▊          | [ 51%]   00:34  -> (00:32 left)
# :HeatingQC:                        |███████████          | [ 52%]   00:35  -> (00:28 left)
# :CentralAir:                       |███████████          | [ 52%]   00:35  -> (00:28 left)
# :CentralAir:                       |███████████▎         | [ 54%]   00:35  -> (00:25 left)
# :Electrical:                       |███████████▎         | [ 54%]   00:35  -> (00:25 left)
# :Electrical:                       |███████████▌         | [ 55%]   00:36  -> (00:23 left)
# :1stFlrSF:                         |███████████▌         | [ 55%]   00:36  -> (00:23 left)
# :1stFlrSF:                         |███████████▊         | [ 56%]   00:38  -> (00:38 left)
# :2ndFlrSF:                         |███████████▊         | [ 56%]   00:38  -> (00:38 left)
# :2ndFlrSF:                         |████████████         | [ 57%]   00:39  -> (00:37 left)
# :LowQualFinSF:                     |████████████         | [ 57%]   00:39  -> (00:37 left)
# :LowQualFinSF:                     |████████████▎        | [ 59%]   00:40  -> (00:36 left)
# :GrLivArea:                        |████████████▎        | [ 59%]   00:40  -> (00:36 left)
# :GrLivArea:                        |████████████▌        | [ 60%]   00:41  -> (00:34 left)
# :BsmtFullBath:                     |████████████▌        | [ 60%]   00:41  -> (00:34 left)
# :BsmtFullBath:                     |████████████▊        | [ 61%]   00:42  -> (00:28 left)
# :BsmtHalfBath:                     |████████████▊        | [ 61%]   00:42  -> (00:28 left)
# :BsmtHalfBath:                     |█████████████        | [ 62%]   00:42  -> (00:25 left)
# :FullBath:                         |█████████████        | [ 62%]   00:42  -> (00:25 left)
# :FullBath:                         |█████████████▎       | [ 63%]   00:43  -> (00:22 left)
# :HalfBath:                         |█████████████▎       | [ 63%]   00:43  -> (00:22 left)
# :HalfBath:                         |█████████████▌       | [ 65%]   00:43  -> (00:19 left)
# :BedroomAbvGr:                     |█████████████▌       | [ 65%]   00:43  -> (00:19 left)
# :BedroomAbvGr:                     |█████████████▊       | [ 66%]   00:44  -> (00:18 left)
# :KitchenAbvGr:                     |█████████████▊       | [ 66%]   00:44  -> (00:18 left)
# :KitchenAbvGr:                     |██████████████       | [ 67%]   00:44  -> (00:17 left)
# :KitchenQual:                      |██████████████       | [ 67%]   00:44  -> (00:17 left)
# :KitchenQual:                      |██████████████▎      | [ 68%]   00:45  -> (00:15 left)
# :TotRmsAbvGrd:                     |██████████████▎      | [ 68%]   00:45  -> (00:15 left)
# :TotRmsAbvGrd:                     |██████████████▌      | [ 70%]   00:46  -> (00:17 left)
# :Functional:                       |██████████████▌      | [ 70%]   00:46  -> (00:17 left)
# :Functional:                       |██████████████▊      | [ 71%]   00:47  -> (00:16 left)
# :Fireplaces:                       |██████████████▊      | [ 71%]   00:47  -> (00:16 left)
# :Fireplaces:                       |███████████████      | [ 72%]   00:47  -> (00:15 left)
# :FireplaceQu:                      |███████████████      | [ 72%]   00:47  -> (00:15 left)
# :FireplaceQu:                      |███████████████▎     | [ 73%]   00:48  -> (00:14 left)
# :GarageType:                       |███████████████▎     | [ 73%]   00:48  -> (00:14 left)
# :GarageType:                       |███████████████▌     | [ 74%]   00:48  -> (00:13 left)
# :GarageYrBlt:                      |███████████████▌     | [ 74%]   00:48  -> (00:13 left)
# :GarageYrBlt:                      |███████████████▉     | [ 76%]   00:49  -> (00:14 left)
# :GarageFinish:                     |███████████████▉     | [ 76%]   00:49  -> (00:14 left)
# :GarageFinish:                     |████████████████▏    | [ 77%]   00:50  -> (00:13 left)
# :GarageCars:                       |████████████████▏    | [ 77%]   00:50  -> (00:13 left)
# :GarageCars:                       |████████████████▍    | [ 78%]   00:51  -> (00:12 left)
# :GarageArea:                       |████████████████▍    | [ 78%]   00:51  -> (00:12 left)
# :GarageArea:                       |████████████████▋    | [ 79%]   00:52  -> (00:13 left)
# :GarageQual:                       |████████████████▋    | [ 79%]   00:52  -> (00:13 left)
# :GarageQual:                       |████████████████▉    | [ 80%]   00:52  -> (00:11 left)
# :GarageCond:                       |████████████████▉    | [ 80%]   00:52  -> (00:11 left)
# :GarageCond:                       |█████████████████▏   | [ 82%]   00:53  -> (00:11 left)
# :PavedDrive:                       |█████████████████▏   | [ 82%]   00:53  -> (00:11 left)
# :PavedDrive:                       |█████████████████▍   | [ 83%]   00:54  -> (00:10 left)
# :WoodDeckSF:                       |█████████████████▍   | [ 83%]   00:54  -> (00:10 left)
# :WoodDeckSF:                       |█████████████████▋   | [ 84%]   00:55  -> (00:10 left)
# :OpenPorchSF:                      |█████████████████▋   | [ 84%]   00:55  -> (00:10 left)
# :OpenPorchSF:                      |█████████████████▉   | [ 85%]   00:57  -> (00:14 left)
# :EnclosedPorch:                    |█████████████████▉   | [ 85%]   00:57  -> (00:14 left)
# :EnclosedPorch:                    |██████████████████▏  | [ 87%]   00:58  -> (00:12 left)
# :3SsnPorch:                        |██████████████████▏  | [ 87%]   00:58  -> (00:12 left)
# :3SsnPorch:                        |██████████████████▍  | [ 88%]   00:59  -> (00:11 left)
# :ScreenPorch:                      |██████████████████▍  | [ 88%]   00:59  -> (00:11 left)
# :ScreenPorch:                      |██████████████████▋  | [ 89%]   01:00  -> (00:09 left)
# :PoolArea:                         |██████████████████▋  | [ 89%]   01:00  -> (00:09 left)
# :PoolArea:                         |██████████████████▉  | [ 90%]   01:01  -> (00:07 left)
# :PoolQC:                           |██████████████████▉  | [ 90%]   01:01  -> (00:07 left)
# :Fence:                            |███████████████████▏ | [ 91%]   01:01  -> (00:06 left)
# :Fence:                            |███████████████████▍ | [ 93%]   01:01  -> (00:04 left)
# :MiscFeature:                      |███████████████████▍ | [ 93%]   01:01  -> (00:04 left)
# :MiscFeature:                      |███████████████████▋ | [ 94%]   01:02  -> (00:03 left)
# :MiscVal:                          |███████████████████▋ | [ 94%]   01:02  -> (00:03 left)
# :MiscVal:                          |███████████████████▉ | [ 95%]   01:03  -> (00:03 left)
# :MoSold:                           |███████████████████▉ | [ 95%]   01:03  -> (00:03 left)
# :MoSold:                           |████████████████████▏| [ 96%]   01:05  -> (00:03 left)
# :YrSold:                           |████████████████████▏| [ 96%]   01:05  -> (00:03 left)
# :YrSold:                           |████████████████████▍| [ 98%]   01:06  -> (00:02 left)
# :SaleType:                         |████████████████████▍| [ 98%]   01:06  -> (00:02 left)
# :SaleType:                         |████████████████████▋| [ 99%]   01:06  -> (00:00 left)
# :SaleCondition:                    |████████████████████▋| [ 99%]   01:06  -> (00:00 left)
# :SaleCondition:                    |█████████████████████| [100%]   01:07  -> (00:00 left)
# :FEATURES DONE:                    |█████████████████████| [100%]   01:07  -> (00:00 left)
#
#                                    |                         | [  0%]   00:00  -> (? left)
# :Processing Pairwise Features:     |                         | [  0%]   00:00  -> (? left)
# :Processing Pairwise Features:     |█                    | [  5%]   00:00  -> (00:09 left)
# :Processing Pairwise Features:     |█▊                   | [  9%]   00:00  -> (00:09 left)
# :Processing Pairwise Features:     |██                   | [ 10%]   00:01  -> (00:15 left)
# :Processing Pairwise Features:     |██▎                  | [ 11%]   00:01  -> (00:19 left)
# :Processing Pairwise Features:     |██▌                  | [ 12%]   00:02  -> (00:21 left)
# :Processing Pairwise Features:     |██▊                  | [ 14%]   00:02  -> (00:24 left)
# :Processing Pairwise Features:     |███                  | [ 15%]   00:02  -> (00:25 left)
# :Processing Pairwise Features:     |███▎                 | [ 16%]   00:03  -> (00:25 left)
# :Processing Pairwise Features:     |███▋                 | [ 17%]   00:03  -> (00:28 left)
# :Processing Pairwise Features:     |███▉                 | [ 19%]   00:04  -> (00:25 left)
# :Processing Pairwise Features:     |████▏                | [ 20%]   00:04  -> (00:24 left)
# :Processing Pairwise Features:     |████▍                | [ 21%]   00:04  -> (00:23 left)
# :Processing Pairwise Features:     |████▋                | [ 22%]   00:05  -> (00:21 left)
# :Processing Pairwise Features:     |████▉                | [ 23%]   00:05  -> (00:20 left)
# :Processing Pairwise Features:     |█████▏               | [ 25%]   00:05  -> (00:21 left)
# :Processing Pairwise Features:     |█████▉               | [ 28%]   00:06  -> (00:16 left)
# :Processing Pairwise Features:     |██████▏              | [ 30%]   00:06  -> (00:16 left)
# :Processing Pairwise Features:     |██████▍              | [ 31%]   00:06  -> (00:17 left)
# :Processing Pairwise Features:     |██████▋              | [ 32%]   00:07  -> (00:17 left)
# :Processing Pairwise Features:     |███████              | [ 33%]   00:07  -> (00:16 left)
# :Processing Pairwise Features:     |███████▌             | [ 36%]   00:07  -> (00:14 left)
# :Processing Pairwise Features:     |███████▊             | [ 37%]   00:08  -> (00:14 left)
# :Processing Pairwise Features:     |████████             | [ 38%]   00:08  -> (00:14 left)
# :Processing Pairwise Features:     |████████▎            | [ 40%]   00:08  -> (00:14 left)
# :Processing Pairwise Features:     |████████▌            | [ 41%]   00:09  -> (00:15 left)
# :Processing Pairwise Features:     |████████▊            | [ 42%]   00:09  -> (00:14 left)
# :Processing Pairwise Features:     |█████████            | [ 43%]   00:09  -> (00:14 left)
# :Processing Pairwise Features:     |█████████▌           | [ 46%]   00:10  -> (00:12 left)
# :Processing Pairwise Features:     |██████████▋          | [ 51%]   00:10  -> (00:09 left)
# :Processing Pairwise Features:     |██████████▉          | [ 52%]   00:11  -> (00:09 left)
# :Processing Pairwise Features:     |███████████▏         | [ 53%]   00:11  -> (00:10 left)
# :Processing Pairwise Features:     |███████████▍         | [ 54%]   00:11  -> (00:10 left)
# :Processing Pairwise Features:     |████████████▍        | [ 59%]   00:11  -> (00:06 left)
# :Processing Pairwise Features:     |████████████▉        | [ 62%]   00:12  -> (00:07 left)
# :Processing Pairwise Features:     |█████████████▍       | [ 64%]   00:12  -> (00:07 left)
# :Processing Pairwise Features:     |█████████████▋       | [ 65%]   00:13  -> (00:07 left)
# :Processing Pairwise Features:     |██████████████       | [ 67%]   00:13  -> (00:07 left)
# :Processing Pairwise Features:     |██████████████▎      | [ 68%]   00:13  -> (00:07 left)
# :Processing Pairwise Features:     |██████████████▊      | [ 70%]   00:14  -> (00:06 left)
# :Processing Pairwise Features:     |███████████████      | [ 72%]   00:14  -> (00:06 left)
# :Processing Pairwise Features:     |███████████████▎     | [ 73%]   00:14  -> (00:06 left)
# :Processing Pairwise Features:     |███████████████▌     | [ 74%]   00:15  -> (00:06 left)
# :Processing Pairwise Features:     |████████████████     | [ 77%]   00:15  -> (00:04 left)
# :Processing Pairwise Features:     |████████████████▎    | [ 78%]   00:15  -> (00:05 left)
# :Processing Pairwise Features:     |████████████████▊    | [ 80%]   00:16  -> (00:04 left)
# :Processing Pairwise Features:     |█████████████████    | [ 81%]   00:16  -> (00:04 left)
# :Processing Pairwise Features:     |█████████████████▎   | [ 83%]   00:17  -> (00:04 left)
# :Processing Pairwise Features:     |██████████████████▍  | [ 88%]   00:17  -> (00:02 left)
# :Processing Pairwise Features:     |██████████████████▉  | [ 90%]   00:17  -> (00:01 left)
# :Processing Pairwise Features:     |███████████████████▍ | [ 93%]   00:18  -> (00:01 left)
# :Processing Pairwise Features:     |███████████████████▋ | [ 94%]   00:18  -> (00:01 left)
# :Processing Pairwise Features:     |████████████████████▍| [ 98%]   00:19  -> (00:00 left)
# :Processing Pairwise Features:     |████████████████████▋| [ 99%]   00:19  -> (00:00 left)
# :Processing Pairwise Features:     |█████████████████████| [100%]   00:19  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:19  -> (00:00 left)
# Creating Associations graph... DONE!

# %% [markdown]
# * "Train" and "Test" are just the names given to represent train and test datasets in sweetviz environment.
# * The target feature is SalePrice.

# %%
train_test_comp_report.show_html(r'./data/House_train_test_comparison.html')

# %% [markdown]
# Here the ones displayed in blue colour represents your train data and the ones displayed in orange represents your test data. As you can see the orange section in your sale price would be missing that is because there is no SalePrice in your test data since that is the target variable.
